# %% [markdown]
# <a href="https://colab.research.google.com/github/hericamachado/Projeto-Imersao-IA/blob/main/Projeto_Briefing_Vis%C3%A3o_de_Mercado_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# Import the Python SDK
import numpy as np
import pandas as pd
import google.generativeai as genai

# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY='AIzaSyDwkOIkwFodOwm3PusuW7m388_Ff4caCaI'
genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-pro')

# Apresentação do sistema
print("Bem-vindo ao Gerador de briefing para campanhas\nVamos iniciar um novo Briefing\n\nVamos iniciar com algumas perguntas)")

# Função solictação do usuario para tipo de campanha
def tipo_campanha(mensagem):
  """
  Função que solicita ao usuário o tipo de campanha e armazena a resposta na variável `tipo_briefing`.

  Argumento:
    mensagem (str): A mensagem a ser exibida ao usuário para solicitar o tipo de campanha.

  Retorno:
    str: O tipo de campanha escolhido pelo usuário ("lançamento", "branding", "conteudo" ou "social").
  """
  while True:
    resposta = input(f"{mensagem} (lançamento/branding/conteudo/social): ").lower()
    if resposta in ["lançamento", "branding", "conteudo", "social"]:
      global tipo_briefing  # Declara `tipo_briefing` como variável global
      tipo_briefing = resposta  # Armazena a resposta na variável `tipo_briefing`
      # Aqui você pode implementar a lógica para criar o briefing com base no tipo escolhido
      return resposta
    else:
      print("Tipo de campanha inválido. Digite uma das opções disponíveis.")

# Função principal para determinar tipo de campanha
def selecao_tipo_briefing():
  """
  Função principal que executa o programa e interage com o usuário.
  """
  tipo_campanha_escolhido = tipo_campanha("Qual tipo de briefing você deseja criar?\n\n")
  if tipo_campanha_escolhido:
    print(f"Ok, vamos criar um briefing para {tipo_campanha_escolhido}.")
    # Aqui você pode implementar a lógica para criar o briefing com base no tipo escolhido
  else:
    print("Tipo de briefing inválido. Tente novamente.")

# Execução do programa
if __name__ == "__main__":
  selecao_tipo_briefing()

#Entradas com informações do usuario

# Entrada do usuário
Cliente = input("Digite o Nome do Cliente: ")
Mercado_Atuacao = input("Qual o mercado de atuação do cliente? ")
Nicho_Mercado = input("Qual a caracteristica de atuação do cliente dentro do mercado? ")
Publico = input("Dê mais informações sobre o público desse projeto: ")
Objetivo_Projeto = input("Qual o objetivo principal desse projeto ou campanha? ")
Resumo_Estrategico = input("Faça um resumo estratégico da ação: ")
Canais_Utilizacao = input("Quais canais de comunicação serão utilizados? ")


#Embedding para buscar informações para o briefing
title = "Lançamento"
sample_text = ("Título: Esse tipo de briefing deve levar em consideração o conteúdo em todos os formatos"
    "\n"
    "Artigo completo:\n"
    "\n"
    "Trazer as etapas de atração, consideração e venda e estrategia de apresentação com o viés de marketing. Considerar Geração de Expectativa: Crie teasers e campanhas de pré-lançamento para gerar expectativa e interesse no produto ou serviço. Eventos de Lançamento: Organize eventos de lançamento para apresentar o produto ou serviço ao público e à imprensa. Ofertas Promocionais: Ofereça descontos, brindes ou outras promoções para incentivar as primeiras compras")

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")

#Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título": "Lançamento",
    "Conteúdo": "Esse tipo de briefing deve levar em consideração uma visão geral, considerando atração para o produto ou serviço de novos usuarios. Trazer as etapas de atração, consideração e venda e estrategia de apresentação com o viés de marketing. Considerar Geração de Expectativa: Crie teasers e campanhas de pré-lançamento para gerar expectativa e interesse no produto ou serviço. Eventos de Lançamento: Organize eventos de lançamento para apresentar o produto ou serviço ao público e à imprensa. Ofertas Promocionais: Ofereça descontos, brindes ou outras promoções para incentivar as primeiras compras"}

DOCUMENT2 = {
    "Título": "Branding",
    "Conteúdo": "Esse tipo de briefing deve levar em consideração a percepção de marca, considerando como pode potencializar a como o mercado entende a empresa. Identidade Visual Forte: Crie uma identidade visual consistente e memorável que represente a personalidade da sua marca. Storytelling: Conte a história da sua marca e conecte-se com o público em um nível emocional. Experiência do Cliente: Crie uma experiência de cliente excepcional que reforce o posicionamento da sua marca. Comunidade: Construa uma comunidade em torno da sua marca para aumentar o engajamento e a fidelidade dos clientes."}

DOCUMENT3 = {
    "Título": "Conteúdo",
    "Conteúdo": "Esse tipo de briefing deve levar em consideração o conteúdo em todos os formatos, considerando a mensagem que está presente em suas redes sociais, canais e site. Diversos Formatos: Utilize diferentes formatos de conteúdo, como artigos, vídeos, infográficos, podcasts, etc., para atender às preferências do público. Otimização para SEO: Otimize seu conteúdo para mecanismos de busca para aumentar a visibilidade e o tráfego orgânico. Promoção do Conteúdo: Promova seu conteúdo nas redes sociais, email marketing e outros canais para alcançar um público mais amplo."}

DOCUMENT3 = {
    "Título": "Social",
    "Conteúdo": "Esse tipo de briefing deve levar em consideração a presença social, considerando a mensagem que está presente em suas redes sociais. Presença Ativa nas Redes Sociais: Crie ou otimize perfis nas principais redes sociais e mantenha uma presença ativa, interagindo com o público e publicando conteúdo regularmente. Conteúdo Engajador: Crie conteúdo envolvente que incentive o compartilhamento, comentários e curtidas. Campanhas Interativas: Promova campanhas interativas, como concursos, enquetes e quizzes, para aumentar o engajamento do público. Análise de Resultados: Analise os resultados das suas ações nas redes sociais para identificar o que funciona melhor e fazer ajustes conforme necessário."}


documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df

model = "models/embedding-001"

def embed_fn(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")["embedding"]

df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df

def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type="RETRIEVAL_QUERY")["embedding"]

  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

consulta = tipo_briefing


#variavel detalhe_briefing com informações detalhadas do tipo de briefing
detalhe_briefing = gerar_e_buscar_consulta(consulta, df, model)


# Exibindo as informações
print("\n**Informações do Briefing do Projeto:**\n\nCliente: "+ Cliente +"\n")
print(f"Cliente: {Cliente}")
print(f"Público: {Publico}")
print(f"Objetivo do Projeto:\n {Objetivo_Projeto}")

#Tratativa IA para criar Briefing

model = genai.GenerativeModel('gemini-pro')
response_mercado = model.generate_content("Faça um resumo geral sobre o mercado de "+ Mercado_Atuacao + "Com as seguintes caracteristicas:"+ Nicho_Mercado +". Considerando as principais necessidades, tendencias e estrategias de aumento de share de mercado, percepção de marca e conteúdo. Os pontos mais relevantes para que um leigo consiga entender as melhores oportunidades de negocio. Organize a informação em sessões e tópicos.")

print("\n**Raio-x do Mercado: "+ Mercado_Atuacao +"\n")
print(response_mercado.text)

print("\n**Briefing***\n\n")

response_briefing = model.generate_content( "Organize a informação em sessões e tópicos (mas expanda e não resuma) e inicie com uma sessão de visão geral. Otimize o texto e as informações considerando que é um projeto de marketing. Ele tem como principal caracteristica" + detalhe_briefing + ". Que tem como iniciativas de estrategia de marketing as seguintes informações: " + Resumo_Estrategico + "para os canais: " + Canais_Utilizacao)

print(response_briefing.text)
# Out:
# Bem-vindo ao Gerador de briefing para campanhas
# Vamos iniciar um novo Briefing
#
# Vamos iniciar com algumas perguntas)
# Qual tipo de briefing você deseja criar?
#
#  (lançamento/branding/conteudo/social): social
# Ok, vamos criar um briefing para social.
# Digite o Nome do Cliente: Globo
# Qual o mercado de atuação do cliente? Entretenimento
# Qual a caracteristica de atuação do cliente dentro do mercado? O maior veiculo de comunicação do Brasil. Com capilaridade e diversos tipos de conteúdos para TV aberta e fechada, além de streming.
# Dê mais informações sobre o público desse projeto: Maior poder aquisitivo que tem caracteristica de consumir tv fechada ou por assinatura
# Qual o objetivo principal desse projeto ou campanha? Vender TV por assinatura
# Faça um resumo estratégico da ação: Ação promocional para garantir contratos mais duradouros com fidelidade de 24 meses mas 40% de desconto no segundo ano
# ...
